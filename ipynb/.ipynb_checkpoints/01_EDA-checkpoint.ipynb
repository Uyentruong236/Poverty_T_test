# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
a_hh = pd.read_csv('../datasets/A_hhold_train.csv',index_col='id')
b_hh = pd.read_csv('../datasets/B_hhold_train.csv',index_col='id')
c_hh = pd.read_csv('../datasets/C_hhold_train.csv',index_col='id')

# %% [markdown]
# ### EDA for Households

# %%
a_hh.head()
# Out:
#       wBXbHZmp SlDKnCuu KAJOWiiw DsKacCdL rtPrBBPl tMJrvvut jdetlNNF maLAYXwi  \
# id
# 46107    JhtDR    GUusz    TuovO    ZYabk    feupP    PHMVg    NDTCU    cLAGr
# 82739    JhtDR    GUusz    TuovO    ZYabk    feupP    PHMVg    NDTCU    sehIp
# 9646     JhtDR    GUusz    BIZns    ZYabk    uxuSS    PHMVg    NDTCU    sehIp
# 10975    JhtDR    GUusz    TuovO    ZYabk    feupP    PHMVg    NDTCU    sehIp
# 16463    JhtDR    alLXR    TuovO    ZYabk    feupP    PHMVg    NDTCU    cLAGr
#
#       vwpsXRGk sArDRIyX   ...   sDGibZrP CsGvKKBJ OLpGAaEu LrDrWRjC JCDeZBXq  \
# id                        ...
# 46107    XAmOF    MwLvg   ...      JqHnW    MaXfS    etZsD    idRwx    LPtkN
# 82739    lwCkE    MwLvg   ...      JqHnW    MaXfS    HxnJy    idRwx    UyAms
# 9646     qNABl    MwLvg   ...      JqHnW    MaXfS    USRak    idRwx    UyAms
# 10975    sPNOc    MwLvg   ...      JqHnW    MaXfS    USRak    idRwx    UyAms
# 16463    NdlDR    MwLvg   ...      JqHnW    MaXfS    etZsD    idRwx    UyAms
# ...

# %%
b_hh.head()
# Out:
#       RzaXNcgd LfWEhutI jXOqJdNL  wJthinfa PTLgvdlQ  ZvEApWrk euTESpHe  \
# id
# 57071    zTghO    pYfmQ    lNhMv        42    RQnVj       103    jpSeC
# 18973    zTghO    pYfmQ    lNhMv        34    iuxWN        -2    OLVWN
# 20151    zTghO    pYfmQ    lNhMv        34    iuxWN       313    OMRWa
# 5730     zTghO    pYfmQ    lNhMv        58    iuxWN       138    jpSeC
# 35033    zTghO    pYfmQ    lNhMv       122    iuxWN        68    OLVWN
#
#       bDVMMSYY aSzMhjgD ZehDbxxy   ...   YVMuyCUV AZVtosGB toZzckhe BkiXyuSp  \
# id                                 ...
# 57071    FDqwJ    rxJJI    IbWRL   ...      nZcTi    pdvWY    LLuZj    qpzpO
# 18973    FDqwJ    ufugi    IbWRL   ...      nZcTi    XrijK    LLuZj    qpzpO
# 20151    FDqwJ    rxJJI    IbWRL   ...      nZcTi    FEjSW    lmjln    qpzpO
# 5730     FDqwJ    rxJJI    IbWRL   ...      nZcTi    XrijK    lmjln    ZZzXr
# 35033    FDqwJ    rxJJI    IbWRL   ...      nZcTi    CRHYU    lmjln    qpzpO
#
# ...

# %%
c_hh.head()
# Out:
#       GRGAYimk DNnBfiSI cNDTCUPU GvTJUYOo vmKoAlVH  LhUIIEHQ DTNyjXJp  \
# id
# 57211    RslOh    SuNUt    gJLrc    EPKkJ    qKiiE         7    XuMYE
# 62519    jPUAt    boDkI    gJLrc    EPKkJ    YXkKd         7    XuMYE
# 11614    OpTiw    boDkI    vURog    EPKkJ    qKiiE         9    XuMYE
# 6470     RslOh    VgxgY    gJLrc    EPKkJ    YXkKd         9    zfhKi
# 33558    IXFlv    VgxgY    kPTaD    EPKkJ    YXkKd         9    XuMYE
#
#        PNAiwXUz ABnhybHK yiuxBjHP   ...   AJHrHUkH PaEKIlvv bFEsoTgJ ihACfisf  \
# id                                  ...
# 57211        -5    QqETe    umyco   ...      laFxs    kBQRJ    qcUVH    AmPtx
# 62519       331    sEJgr    yYwlq   ...      laFxs    kBQRJ    eusFW    AmPtx
# 11614        -1    sEJgr    umyco   ...      laFxs    oUXSJ    eusFW    AmPtx
# 6470         -5    sEJgr    umyco   ...      laFxs    kBQRJ    jqrBN    AmPtx
# 33558        23    sEJgr    umyco   ...      laFxs    kBQRJ    eusFW    AmPtx
#
# ...

# %%
print(a_hh.info())
print(b_hh.info())
print(c_hh.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8203 entries, 46107 to 39832
# Columns: 345 entries, wBXbHZmp to country
# dtypes: bool(1), float64(2), int64(2), object(340)
# memory usage: 21.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3255 entries, 57071 to 4923
# Columns: 442 entries, RzaXNcgd to country
# dtypes: bool(1), float64(9), int64(14), object(418)
# memory usage: 11.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6469 entries, 57211 to 7646
# Columns: 164 entries, GRGAYimk to country
# dtypes: bool(1), float64(1), int64(29), object(133)
# memory usage: 8.1+ MB
# None

# %%
a_hh.describe()
# Out:
#           nEsgxvAq     OMtioXZZ     YFMZwKrU     TiwRslOh
# count  8203.000000  8203.000000  8203.000000  8203.000000
# mean     -7.590638    17.464464    -2.985615    -4.191028
# std       5.810942    10.853654     0.896245     4.472567
# min     -70.000000  -127.000000    -4.000000   -31.000000
# 25%     -10.000000    12.000000    -4.000000    -7.000000
# 50%      -4.000000    12.000000    -3.000000    -3.000000
# 75%      -4.000000    21.000000    -2.000000    -1.000000
# max      -4.000000   111.000000     1.000000     3.000000

# %%
b_hh.describe()
# Out:
#           wJthinfa     ZvEApWrk     vuQrLzvK    FGWqGkmD     qrOrXLPM  \
# count  3255.000000  3255.000000  3255.000000  602.000000  3255.000000
# mean     43.381260    96.040860    17.427343   -7.509967    22.203379
# std      22.728441   105.556895    72.057949    9.499141     6.962658
# min    -126.000000    -2.000000  -125.000000  -53.000000     8.000000
# 25%      26.000000    33.000000   -39.000000  -13.000000    16.000000
# 50%      42.000000    68.000000    27.000000   -8.000000    24.000000
# 75%      58.000000   138.000000    77.000000    2.000000    24.000000
# max     122.000000  1069.000000   127.000000    2.000000    48.000000
#
#           BXOWgPgL    umkFMfvA     McFBIGsm     NjDdhqIe     rCVqiShm  \
# count  2504.000000  890.000000  2504.000000  3255.000000  3255.000000
# mean    158.354633  -33.279775   301.106230    88.597849   -48.195392
# std     124.535287    8.231694   155.904844   107.268927    52.981575
# ...

# %%
c_hh.describe()
# Out:
#           LhUIIEHQ     PNAiwXUz     jmsRIiqp     NONtAKOM     kLAQgdly  \
# count  6469.000000  6469.000000  6469.000000  6469.000000  6469.000000
# mean      7.899366    22.646932    10.876179    -6.674911  -298.008966
# std       1.482295    78.914475     9.164273    10.723440   286.793836
# min       7.000000    -9.000000     1.000000  -100.000000 -4150.000000
# 25%       7.000000    -5.000000     1.000000   -10.000000  -430.000000
# 50%       7.000000    -1.000000     8.000000    -4.000000  -250.000000
# 75%       9.000000     7.000000    15.000000     2.000000   -10.000000
# max      35.000000   711.000000    85.000000     8.000000   -10.000000
#
#           WWuPOkor     CtFxPQPT     GIwNbAsH     qLDzvjiU     detlNNFh  \
# count  6469.000000  6469.000000  6469.000000  6469.000000  6469.000000
# mean      3.427887   -68.832586    -3.166950     0.315659     2.667337
# std       2.999990   159.918843     6.366799     1.264827    28.862018
# ...

# %% [markdown]
# ### can't combine train data since there are different # of columns in each country dataset

# %%
# %matplotlib inline

# %%
fig = plt.figure(figsize=(12,17))
fig.add_subplot(3,2,1)
sns.countplot(x ='poor', hue='poor', data=a_hh)
plt.title('Country A: Household')

fig.add_subplot(3,2,2)
sns.countplot('poor', hue='poor', data=a_indiv)
plt.title('Country A: Indiv')

fig.add_subplot(3,2,3)
sns.countplot('poor', hue='poor', data=b_hh)
plt.title('Country B: Household')

fig.add_subplot(3,2,4)
sns.countplot('poor', hue='poor', data=b_indiv)
plt.title('Country B: Indiv')

fig.add_subplot(3,2,5)
sns.countplot('poor', hue='poor', data=c_hh)
plt.title('Country C: Household')

fig.add_subplot(3,2,6)
sns.countplot('poor', hue='poor', data=c_indiv)
plt.title('Country C: Indiv')

# %%
a_hh.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# country     0
# wwfmpuWA    0
# OMtioXZZ    0
# bIBQTaHw    0
# KcArMKAe    0
# ofhkZaYa    0
# VtcDnwsf    0
# TFrimNtw    0
# enTUTSQi    0
# LjvKYNON    0
# dtype: int64

# %%
b_hh.isnull().sum().sort_values(ascending=False).head(15)
# Out:
# IrxBnWxE    2983
# dnlnKrAg    2723
# FGWqGkmD    2653
# umkFMfvA    2365
# aAufyreG    2346
# BRzuVmyf    1461
# McFBIGsm     751
# OSmfjCbE     751
# BXOWgPgL     751
# GUcFqgkw       0
# TGealZJe       0
# country        0
# XVMSrDew       0
# kYlvcljE       0
# xhnuEJkJ       0
# dtype: int64

# %%
c_hh.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# country     0
# dgGsziwz    0
# rqGTeUtu    0
# tXjyOtiS    0
# izNLFWMH    0
# detlNNFh    0
# tPfjVDpu    0
# lGhmlsZv    0
# xyzchLjk    0
# qLDzvjiU    0
# dtype: int64

# %% [markdown]
# ### EDA of Individual datasets

# %%
a_indiv = pd.read_csv('../datasets/A_indiv_train.csv',index_col='id')
b_indiv = pd.read_csv('../datasets/B_indiv_train.csv',index_col='id')
c_indiv = pd.read_csv('../datasets/C_indiv_train.csv',index_col='id')

# %%
print(a_indiv.shape)
print(b_indiv.shape)
print(c_indiv.shape)
# Out:
# (37560, 43)
# (20252, 226)
# (29913, 43)

# %%
df_list = [a_indiv, b_indiv, c_indiv]

# %%
for df in df_list:
    print(df.isnull().sum().sort_values(ascending=False).head(20))
# Out:
# OdXpbPGJ    6268
# country        0
# qYRZCuJD       0
# AoLwmlEH       0
# AQpdiRUz       0
# cxWuAOZv       0
# igHwZsYz       0
# UsmeXdIS       0
# XacGrSou       0
# hOamrctW       0
# FPQrjGnS       0
# KsFoQcUV       0
# CRLlSiFu       0
# XONDGWjH       0
# eXbOkwhI       0
# SWoXNmPc       0
# gtnNTNam       0
# MzEtIdUF       0
# CaukPfUC       0
# HeUgMnzF       0
# dtype: int64
# AJgudnHB    20231
# DYgxQeEi    20204
# sIiSADFG    20185
# hdDTwJhQ    20153
# jfsTwowc    20116
# WmKLEUcd    19898
# nxAFXxLQ    19891
# MGfpfHam    19814
# uDmhgsaQ    19814
# HZqPmvkr    19814
# DtcKwIEv    19259
# ETgxnJOM    19249
# qlLzyqpP    19067
# fyfDnyQk    18600
# unRAgFtX    18600
# sWElQwuC    18599
# tzYvQeOb    18227
# iZhWxnWa    18110
# NfpXxGQk    16448
# WqEZQuJP    14866
# dtype: int64
# country     0
# gBTGbFhG    0
# bsMfXBld    0
# wXJsPzSl    0
# FRcdTUFo    0
# vWNISgEA    0
# tOfmAJyI    0
# TfEUOijE    0
# CggtnNTN    0
# XKQWlRjk    0
# IThGOCux    0
# ...
